# %%
import numpy as np
a=np.array([10,45,78,66])

# %%
a.shape  # It is tuple of integers indicating size of array in each dimension
# Out:
# (4,)

# %%
a[2] #accessing array element
# Out:
# 78

# %%
type(a) #type of a
# Out:
# numpy.ndarray

# %%
a.dtype #data type of arrays elements
# Out:
# dtype('int64')

# %%
a.size   #number of elements in the array
# Out:
# 4

# %%
a.ndim  #check the dimension  of array
# Out:
# 1

# %%
#using universal functions like max(), mean() and np.pi

# %%
np.pi #gives value of pi=3.14
x=np.array([0,np.pi/2,np.pi])

# %%
y=np.cos(x)
y
# Out:
# array([ 1.000000e+00,  6.123234e-17, -1.000000e+00])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x,y)

# %%
'''using universal function linspace in numpy   
 it divides the range in equal parts. Lets see som examples below'''
a=np.linspace(-2,2,5)
a
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
''' we will use linspace to plot graph'''
x=np.linspace(0,2*np.pi,100)
y=np.sin(x) #one cam use cos or tan 

import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x,y)

# %%
x=np.linspace(0,2*np.pi,100)
y=np.cos(x)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x,y)

# %%
x=np.linspace(0,2*np.pi,100)
y=np.tan(x)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x,y)

# %%
A = np.mat('4 1; 14 1') 
B = np.mat('5 2; 5 2') 
C = np.mat('8 4; 6 6') 
a = np.bmat([[A, B], [C, A]]) 
a
# Out:
# matrix([[ 4,  1,  5,  2],
#         [14,  1,  5,  2],
#         [ 8,  4,  4,  1],
#         [ 6,  6, 14,  1]])

# %%
import re
re.split(r`[a-c]`, `0a3B6`, re.I)
# Out:
#   File "<ipython-input-63-86f530df4960>", line 2
#     re.split(r`[a-c]`, `0a3B6`, re.I)
#               ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline
data = [np.random.normal(0, std, 100) for std in range(1, 4)] plt.boxcox(data, vert=True)
# Out:
#   File "<ipython-input-71-02aa45662f89>", line 4
#     data = [np.random.normal(0, std, 100) for std in range(1, 4)] plt.boxcox(data, vert=True)
#                                                                     ^
# SyntaxError: invalid syntax
